# %% [markdown]
# <a href="https://colab.research.google.com/github/Tolureis/CMPE-460-Deep-Learning/blob/main/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-7sv3a3sk
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-7sv3a3sk
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.11.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=4b71681a359cf5c3f1de5c966c8ba17668ab01d93c1107b5a22398097115323e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xm42pfws/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
    # 1. Convolution: input=(batch,1,40), output=(batch,15,19)
    nn.Conv1d(in_channels=1, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),

    # 2. Convolution: input=(batch,15,19), output=(batch,15,9)
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),

    # 3. Convolution: input=(batch,15,9), output=(batch,15,4)
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),

    # 7. Flatten: (15 channels × 4 length) → 60
    nn.Flatten(),

    # 8. Linear: 60 → 10 output classes
    nn.Linear(60, 10)
)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 2.063663, train error 80.20,  val loss 2.073073, percent error 80.70
# Epoch     1, train loss 1.696736, train error 68.97,  val loss 1.720075, percent error 72.50
# Epoch     2, train loss 1.514206, train error 60.70,  val loss 1.534266, percent error 61.50
# Epoch     3, train loss 1.275764, train error 52.67,  val loss 1.279719, percent error 54.30
# Epoch     4, train loss 1.298412, train error 54.83,  val loss 1.314994, percent error 58.50
# Epoch     5, train loss 1.245830, train error 50.72,  val loss 1.240406, percent error 52.10
# Epoch     6, train loss 1.103077, train error 45.12,  val loss 1.120865, percent error 48.00
# Epoch     7, train loss 1.006413, train error 41.12,  val loss 1.046093, percent error 44.50
# Epoch     8, train loss 0.885748, train error 36.28,  val loss 0.911360, percent error 36.70
# Epoch     9, train loss 0.764093, train error 30.60,  val loss 0.794030, percent error 33.40
# Epoch    10, train loss 0.665886, train error 26.62,  val loss 0.726495, percent error 28.90
# Epoch    11, train loss 0.598980, train error 23.12,  val loss 0.660007, percent error 26.50
# Epoch    12, train loss 0.552517, train error 20.93,  val loss 0.614942, percent error 24.70
# Epoch    13, train loss 0.452621, train error 18.03,  val loss 0.557467, percent error 22.60
# Epoch    14, train loss 0.404585, train error 14.82,  val loss 0.501375, percent error 19.00
# Epoch    15, train loss 0.394992, train error 14.43,  val loss 0.521720, percent error 19.40
# Epoch    16, train loss 0.329300, train error 12.50,  val loss 0.460324, percent error 16.90
# Epoch    17, train loss 0.355436, train error 13.15,  val loss 0.488985, percent error 18.90
# Epoch    18, train loss 0.301733, train error 11.00,  val loss 0.412139, percent error 14.80
# Epoch    19, train loss 0.344613, train error 12.28,  val loss 0.489920, percent error 16.90
# Epoch    20, train loss 0.206397, train error 6.88,  val loss 0.347426, percent error 12.30
# Epoch    21, train loss 0.199631, train error 6.95,  val loss 0.353744, percent error 12.60
# Epoch    22, train loss 0.195316, train error 6.88,  val loss 0.367428, percent error 12.10
# Epoch    23, train loss 0.185265, train error 6.32,  val loss 0.345935, percent error 11.00
# Epoch    24, train loss 0.180732, train error 6.35,  val loss 0.369009, percent error 12.40
# Epoch    25, train loss 0.164696, train error 5.43,  val loss 0.354510, percent error 12.40
# Epoch    26, train loss 0.166160, train error 5.55,  val loss 0.347430, percent error 11.60
# Epoch    27, train loss 0.153434, train error 5.12,  val loss 0.348642, percent error 10.80
# Epoch    28, train loss 0.147700, train error 4.90,  val loss 0.318847, percent error 10.20
# Epoch    29, train loss 0.137135, train error 4.68,  val loss 0.330902, percent error 11.30
# Epoch    30, train loss 0.147126, train error 4.97,  val loss 0.337093, percent error 11.10
# Epoch    31, train loss 0.145772, train error 5.15,  val loss 0.368017, percent error 12.10
# Epoch    32, train loss 0.133007, train error 4.22,  val loss 0.348687, percent error 10.70
# Epoch    33, train loss 0.126698, train error 4.28,  val loss 0.340038, percent error 10.60
# Epoch    34, train loss 0.140769, train error 4.78,  val loss 0.353600, percent error 11.10
# Epoch    35, train loss 0.122296, train error 4.22,  val loss 0.357762, percent error 11.20
# Epoch    36, train loss 0.112313, train error 3.85,  val loss 0.339100, percent error 10.50
# Epoch    37, train loss 0.104525, train error 3.43,  val loss 0.342166, percent error 10.50
# Epoch    38, train loss 0.101920, train error 3.22,  val loss 0.345202, percent error 10.80
# Epoch    39, train loss 0.089265, train error 2.75,  val loss 0.325800, percent error 9.70
# Epoch    40, train loss 0.086906, train error 2.47,  val loss 0.320641, percent error 10.50
# Epoch    41, train loss 0.079224, train error 2.25,  val loss 0.327494, percent error 9.80
# Epoch    42, train loss 0.094841, train error 3.40,  val loss 0.366293, percent error 10.60
# Epoch    43, train loss 0.081387, train error 2.32,  val loss 0.348642, percent error 10.70
# Epoch    44, train loss 0.075223, train error 2.05,  val loss 0.336155, percent error 10.40
# Epoch    45, train loss 0.070790, train error 1.82,  val loss 0.336456, percent error 9.80
# Epoch    46, train loss 0.072372, train error 1.82,  val loss 0.337101, percent error 9.80
# Epoch    47, train loss 0.078680, train error 2.43,  val loss 0.349107, percent error 10.00
# Epoch    48, train loss 0.077534, train error 2.22,  val loss 0.350577, percent error 10.30
# Epoch    49, train loss 0.070499, train error 1.93,  val loss 0.348161, percent error 9.70
# Epoch    50, train loss 0.067243, train error 1.62,  val loss 0.351020, percent error 9.90
# Epoch    51, train loss 0.064785, train error 1.60,  val loss 0.341789, percent error 9.70
# Epoch    52, train loss 0.059884, train error 1.35,  val loss 0.351199, percent error 9.90
# Epoch    53, train loss 0.064509, train error 1.57,  val loss 0.356567, percent error 10.70
# Epoch    54, train loss 0.058108, train error 1.30,  val loss 0.360496, percent error 9.80
# Epoch    55, train loss 0.058121, train error 1.28,  val loss 0.348833, percent error 9.80
# Epoch    56, train loss 0.057975, train error 1.38,  val loss 0.361458, percent error 9.90
# Epoch    57, train loss 0.055090, train error 1.25,  val loss 0.358766, percent error 9.90
# Epoch    58, train loss 0.056530, train error 1.38,  val loss 0.362459, percent error 9.90
# Epoch    59, train loss 0.058802, train error 1.62,  val loss 0.373641, percent error 10.40
# Epoch    60, train loss 0.049478, train error 1.03,  val loss 0.363419, percent error 10.30
# Epoch    61, train loss 0.049751, train error 1.07,  val loss 0.368746, percent error 9.80
# Epoch    62, train loss 0.048683, train error 1.12,  val loss 0.368222, percent error 9.80
# Epoch    63, train loss 0.047692, train error 0.97,  val loss 0.369802, percent error 9.40
# Epoch    64, train loss 0.047800, train error 0.90,  val loss 0.370995, percent error 9.70
# Epoch    65, train loss 0.047423, train error 0.97,  val loss 0.369502, percent error 9.60
# Epoch    66, train loss 0.046071, train error 0.90,  val loss 0.368340, percent error 9.90
# Epoch    67, train loss 0.045766, train error 0.97,  val loss 0.373081, percent error 9.70
# Epoch    68, train loss 0.045783, train error 0.97,  val loss 0.376838, percent error 9.70
# Epoch    69, train loss 0.044809, train error 0.80,  val loss 0.374655, percent error 10.00
# Epoch    70, train loss 0.044626, train error 0.82,  val loss 0.382204, percent error 9.80
# Epoch    71, train loss 0.043852, train error 0.82,  val loss 0.377313, percent error 9.80
# Epoch    72, train loss 0.042670, train error 0.78,  val loss 0.377344, percent error 9.70
# Epoch    73, train loss 0.042746, train error 0.68,  val loss 0.381748, percent error 9.60
# Epoch    74, train loss 0.043373, train error 0.88,  val loss 0.377923, percent error 10.20
# Epoch    75, train loss 0.042002, train error 0.68,  val loss 0.384039, percent error 10.20
# Epoch    76, train loss 0.041415, train error 0.72,  val loss 0.385467, percent error 9.80
# Epoch    77, train loss 0.040696, train error 0.65,  val loss 0.382223, percent error 9.90
# Epoch    78, train loss 0.040182, train error 0.65,  val loss 0.386751, percent error 9.70
# Epoch    79, train loss 0.040569, train error 0.68,  val loss 0.388971, percent error 10.20
# Epoch    80, train loss 0.039203, train error 0.60,  val loss 0.386425, percent error 9.70
# Epoch    81, train loss 0.039271, train error 0.65,  val loss 0.389038, percent error 9.50
# Epoch    82, train loss 0.038706, train error 0.57,  val loss 0.391401, percent error 9.50
# Epoch    83, train loss 0.038415, train error 0.65,  val loss 0.389232, percent error 9.40
# Epoch    84, train loss 0.038569, train error 0.60,  val loss 0.392188, percent error 9.60
# Epoch    85, train loss 0.038187, train error 0.68,  val loss 0.390531, percent error 9.90
# Epoch    86, train loss 0.037575, train error 0.50,  val loss 0.393152, percent error 9.70
# Epoch    87, train loss 0.038270, train error 0.62,  val loss 0.394541, percent error 9.50
# Epoch    88, train loss 0.037317, train error 0.60,  val loss 0.393115, percent error 9.30
# Epoch    89, train loss 0.036973, train error 0.53,  val loss 0.393931, percent error 9.50
# Epoch    90, train loss 0.036970, train error 0.55,  val loss 0.394852, percent error 9.90
# Epoch    91, train loss 0.036879, train error 0.55,  val loss 0.396513, percent error 9.40
# Epoch    92, train loss 0.036571, train error 0.53,  val loss 0.397382, percent error 9.40
# Epoch    93, train loss 0.036194, train error 0.50,  val loss 0.396748, percent error 9.90
# Epoch    94, train loss 0.036501, train error 0.55,  val loss 0.396696, percent error 9.70
# Epoch    95, train loss 0.035850, train error 0.53,  val loss 0.397321, percent error 9.90
# Epoch    96, train loss 0.035890, train error 0.57,  val loss 0.397417, percent error 9.50
# Epoch    97, train loss 0.035865, train error 0.50,  val loss 0.401693, percent error 9.60
# Epoch    98, train loss 0.035547, train error 0.45,  val loss 0.399091, percent error 10.00
# Epoch    99, train loss 0.035295, train error 0.43,  val loss 0.401211, percent error 9.80
